# %% [markdown]
# # Calculator Project
#
# Let's make a little calculator that can add, subtract, divide, and multiply.
#
# With a little scaffolding (provided below), you absolutely have the skills to implement this.
#
# Here are the general steps, matched to the concepts you learned:
#
# 1. Ask for the first number
#   - `input()` via the `input_number()` function
# 2. Ask for the operand (+, -, *, or /)
#   - `input()`
#   - - `while` loop to let the user enter numbers until they enter a valid one!
# 3. Check if the operand is valid
#   - `if` statements
#   - `while` loop to let the user enter operands until they enter a valid one!
# 3. Ask for the second number
#   - `input()` via the `input_number()` function
#   - `while` loop to let the user enter numbers until they enter a valid one!
# 4. Do the calculation
#   - `a + b` / `a - b` / etc. (see 3_conditionals.ipynb)
# 5. Print the result
#   - `print()` (this is already provided in the scaffolding code)
#
# If you get an error, read it from **bottom to top**, and see if you can find a solution. Some tips and tricks are provided below the code.

# %%
# You'll need the input_number function for this, so I've pasted it here:
def input_number(prompt):
  value = input(prompt)

  try:
    return int(value)
  except ValueError:
    return None

print("> Python Calculator <")

# Ask for the first number
### YOUR CODE HERE ###

# Ask for the operand
operand = input("Do you want to add (+), subtract (-), multiply (*), or divide (/)? ")

# Ask for the second number
### YOUR CODE HERE ###

# Perform the calculation
if operand == "+":
  result = first_number + second_number
### YOUR CODE HERE ###
# What if the operand is invalid?

# Print the result
print(first_number + " " + operand + " " + second_number + " = " + result)

# %% [markdown]
# # Tips and Tricks / FAQ: Calculator
#
# ## Look at previous notebooks!
#
# Need help with `if` statements? Check out `3_conditionals.ipynb`! Help with types and type casting? Try `6_type_casting.ipynb`.
#
# ## Give it a Google!
#
# Try Googling the error you're getting. When coding, remember that, generally, **the most important information is at the bottom of the error**, not the top.
#
# ## Avoid asking ChatGPT
#
# ChatGPT will probably give you the entire solution. If that's what you're after, go for it, but it's not great for learning.
#
# ## How do I access the solution?
#
# VSCode (this text editor) can't read .zip files.
#
# <details>
#   <summary>If you really want to view the solution, click here.</summary>
#
#   To view the solution, open a terminal (press Ctrl+` (the key to the left of the number 1)),
#   then enter these commands:
#
#   - `cd notebooks`
#   - `unzip 10_calculator_solution.zip`
#
#   You should now see `10_calculator_solution.ipynb` in the sidebar - open it to view the solution.
#
# </details>
